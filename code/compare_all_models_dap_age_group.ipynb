# %% [markdown]
# <a href="https://colab.research.google.com/github/pabloinsente/CovNet_Human_Drawings/blob/master/compare_all_models_dap_age_group.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Model comparison age-group classification Draw-a-Person

# %%
import pandas as pd

# %% [markdown]
# ## Read in classification report datasets

# %%
# Import data / for now I'll directly upload data to Colab
# Replace with ! git clone https://github.com/pabloinsente/CovNet_Human_Drawings later

# %%
# read csv as dataframe
net_df = pd.read_csv('classification_report_dap_1.csv') 
ml_df = pd.read_csv('classification_report_dap_ml_classifiers.csv')

print('neural nets', net_df.shape)
print('classifiers', ml_df.shape)
# Out:
# neural nets (10, 15)
# classifiers (6, 15)

# %%
# Explore neural nets dataset
net_df.head()
# Out:
#    Unnamed: 0                  Criteria  True_Negatives  False_Positives  \
# 0           0                       acc              50               15
# 1           1              fmeasure_acc              50               15
# 2           2                recall_acc              50               15
# 3           3             precision_acc              50               15
# 4           4  matthews_correlation_acc              50               15
#
#    False_Negatives  True_Positives  True_Negatives_Per  False_Positives_Per  \
# 0                7               6            0.769231             0.230769
# 1                7               6            0.769231             0.230769
# 2                7               6            0.769231             0.230769
# 3                7               6            0.769231             0.230769
# 4                7               6            0.769231             0.230769
#
#    False_Negatives_Per  True_Positives_Per  Hit_Rate  False_Alarm_Rate  \
# 0             0.538462            0.461538  0.461538          0.230769
# 1             0.538462            0.461538  0.461538          0.230769
# 2             0.538462            0.461538  0.461538          0.230769
# 3             0.538462            0.461538  0.461538          0.230769
# 4             0.538462            0.461538  0.461538          0.230769
#
#    d_sensitivity    c_bias  Test_Accuracy_Score
# 0       0.639757  0.416437             0.717949
# 1       0.639757  0.416437             0.717949
# 2       0.639757  0.416437             0.717949
# 3       0.639757  0.416437             0.717949
# 4       0.639757  0.416437             0.717949

# %%
# Explore classifiers dataset
ml_df.head()
# Out:
#    Unnamed: 0                   Model  True_Negatives  False_Positives  \
# 0           0      LogisticRegression              60                3
# 1           1                     SVC              62                1
# 2           2  DecisionTreeClassifier              50               13
# 3           3              GaussianNB              55                8
# 4           4  RandomForestClassifier              63                0
#
#    False_Negatives  True_Positives  True_Negatives_Per  False_Positives_Per  \
# 0               14               1            0.952381             0.047619
# 1               15               0            0.984127             0.015873
# 2               13               2            0.793651             0.206349
# 3               14               1            0.873016             0.126984
# 4               15               0            1.000000             0.000000
#
#    False_Negatives_Per  True_Positives_Per  Hit_Rate  False_Alarm_Rate  \
# 0             0.933333            0.066667  0.066667          0.047619
# 1             1.000000            0.000000  0.033333          0.015873
# 2             0.866667            0.133333  0.133333          0.206349
# 3             0.933333            0.066667  0.066667          0.126984
# 4             1.000000            0.000000  0.033333          0.007937
#
#    d_sensitivity    c_bias  Test_Accuracy_Score
# 0       0.167305  1.584739             0.782051
# 1       0.313679  1.990754             0.794872
# 2      -0.291617  0.964963             0.666667
# 3      -0.360322  1.320925             0.717949
# 4       0.577908  2.122868             0.807692

# %% [markdown]
# ## Merge data

# %%
# Rename net_df "Criteria" to "Model" to merge
net_df.rename(columns={'Criteria': 'Model'}, inplace=True)
net_df.head(2)
# Out:
#    Unnamed: 0         Model  True_Negatives  False_Positives  False_Negatives  \
# 0           0           acc              50               15                7
# 1           1  fmeasure_acc              50               15                7
#
#    True_Positives  True_Negatives_Per  False_Positives_Per  \
# 0               6            0.769231             0.230769
# 1               6            0.769231             0.230769
#
#    False_Negatives_Per  True_Positives_Per  Hit_Rate  False_Alarm_Rate  \
# 0             0.538462            0.461538  0.461538          0.230769
# 1             0.538462            0.461538  0.461538          0.230769
#
#    d_sensitivity    c_bias  Test_Accuracy_Score
# 0       0.639757  0.416437             0.717949
# 1       0.639757  0.416437             0.717949

# %%
# Merge datasets
df = pd.concat([net_df, ml_df]) 
df = df.drop(df.columns[0], axis=1) # drop index col
df = df.reset_index(drop=True) # reset index
df
# Out:
#                            Model  True_Negatives  False_Positives  \
# 0                            acc              50               15
# 1                   fmeasure_acc              50               15
# 2                     recall_acc              50               15
# 3                  precision_acc              50               15
# 4       matthews_correlation_acc              50               15
# 5                        val_acc              54               11
# 6               val_fmeasure_acc              51               14
# 7                 val_recall_acc              35               30
# 8              val_precision_acc              50               15
# 9   val_matthews_correlation_acc              50               15
# 10            LogisticRegression              60                3
# 11                           SVC              62                1
# 12        DecisionTreeClassifier              50               13
# 13                    GaussianNB              55                8
# 14        RandomForestClassifier              63                0
# 15    GradientBoostingClassifier              58                5
#
#     False_Negatives  True_Positives  True_Negatives_Per  False_Positives_Per  \
# 0                 7               6            0.769231             0.230769
# 1                 7               6            0.769231             0.230769
# 2                 7               6            0.769231             0.230769
# 3                 7               6            0.769231             0.230769
# 4                 7               6            0.769231             0.230769
# 5                 9               4            0.830769             0.169231
# 6                 7               6            0.784615             0.215385
# 7                 5               8            0.538462             0.461538
# 8                 7               6            0.769231             0.230769
# 9                 7               6            0.769231             0.230769
# 10               14               1            0.952381             0.047619
# 11               15               0            0.984127             0.015873
# 12               13               2            0.793651             0.206349
# 13               14               1            0.873016             0.126984
# 14               15               0            1.000000             0.000000
# 15               15               0            0.920635             0.079365
#
#     False_Negatives_Per  True_Positives_Per  Hit_Rate  False_Alarm_Rate  \
# 0              0.538462            0.461538  0.461538          0.230769
# 1              0.538462            0.461538  0.461538          0.230769
# 2              0.538462            0.461538  0.461538          0.230769
# 3              0.538462            0.461538  0.461538          0.230769
# 4              0.538462            0.461538  0.461538          0.230769
# 5              0.692308            0.307692  0.307692          0.169231
# 6              0.538462            0.461538  0.461538          0.215385
# 7              0.384615            0.615385  0.615385          0.461538
# 8              0.538462            0.461538  0.461538          0.230769
# 9              0.538462            0.461538  0.461538          0.230769
# 10             0.933333            0.066667  0.066667          0.047619
# 11             1.000000            0.000000  0.033333          0.015873
# 12             0.866667            0.133333  0.133333          0.206349
# 13             0.933333            0.066667  0.066667          0.126984
# 14             1.000000            0.000000  0.033333          0.007937
# 15             1.000000            0.000000  0.033333          0.079365
#
#     d_sensitivity    c_bias  Test_Accuracy_Score
# 0        0.639757  0.416437             0.717949
# 1        0.639757  0.416437             0.717949
# 2        0.639757  0.416437             0.717949
# 3        0.639757  0.416437             0.717949
# 4        0.639757  0.416437             0.717949
# 5        0.454807  0.729806             0.743590
# 6        0.691317  0.442217             0.730769
# 7        0.389940 -0.098411             0.551282
# 8        0.639757  0.416437             0.717949
# 9        0.639757  0.416437             0.717949
# 10       0.167305  1.584739             0.782051
# 11       0.313679  1.990754             0.794872
# 12      -0.291617  0.964963             0.666667
# 13      -0.360322  1.320925             0.717949
# 14       0.577908  2.122868             0.807692
# 15      -0.424559  1.621635             0.743590

# %%
# Subset dataset keeping (1) the best neural net AND (2) all the ML classifiers
keep = ['val_fmeasure_acc', 'LogisticRegression', 'SVC', 'DecisionTreeClassifier',
        'GaussianNB', 'RandomForestClassifier', 'GradientBoostingClassifier' ]

df_report = df.loc[df['Model'].isin(keep)]
df_report = df_report.reset_index(drop=True) # reset index

df_report
# Out:
#                         Model  True_Negatives  False_Positives  \
# 0            val_fmeasure_acc              51               14
# 1          LogisticRegression              60                3
# 2                         SVC              62                1
# 3      DecisionTreeClassifier              50               13
# 4                  GaussianNB              55                8
# 5      RandomForestClassifier              63                0
# 6  GradientBoostingClassifier              58                5
#
#    False_Negatives  True_Positives  True_Negatives_Per  False_Positives_Per  \
# 0                7               6            0.784615             0.215385
# 1               14               1            0.952381             0.047619
# 2               15               0            0.984127             0.015873
# 3               13               2            0.793651             0.206349
# 4               14               1            0.873016             0.126984
# 5               15               0            1.000000             0.000000
# 6               15               0            0.920635             0.079365
#
#    False_Negatives_Per  True_Positives_Per  Hit_Rate  False_Alarm_Rate  \
# 0             0.538462            0.461538  0.461538          0.215385
# 1             0.933333            0.066667  0.066667          0.047619
# 2             1.000000            0.000000  0.033333          0.015873
# 3             0.866667            0.133333  0.133333          0.206349
# 4             0.933333            0.066667  0.066667          0.126984
# 5             1.000000            0.000000  0.033333          0.007937
# 6             1.000000            0.000000  0.033333          0.079365
#
#    d_sensitivity    c_bias  Test_Accuracy_Score
# 0       0.691317  0.442217             0.730769
# 1       0.167305  1.584739             0.782051
# 2       0.313679  1.990754             0.794872
# 3      -0.291617  0.964963             0.666667
# 4      -0.360322  1.320925             0.717949
# 5       0.577908  2.122868             0.807692
# 6      -0.424559  1.621635             0.743590

# %%
# Change val_fmeasure_acc label

df_report.at[0, 'Model'] = 'Neural_Net'
df_report
# Out:
#                         Model  True_Negatives  False_Positives  \
# 0                  Neural_Net              51               14
# 1          LogisticRegression              60                3
# 2                         SVC              62                1
# 3      DecisionTreeClassifier              50               13
# 4                  GaussianNB              55                8
# 5      RandomForestClassifier              63                0
# 6  GradientBoostingClassifier              58                5
#
#    False_Negatives  True_Positives  True_Negatives_Per  False_Positives_Per  \
# 0                7               6            0.784615             0.215385
# 1               14               1            0.952381             0.047619
# 2               15               0            0.984127             0.015873
# 3               13               2            0.793651             0.206349
# 4               14               1            0.873016             0.126984
# 5               15               0            1.000000             0.000000
# 6               15               0            0.920635             0.079365
#
#    False_Negatives_Per  True_Positives_Per  Hit_Rate  False_Alarm_Rate  \
# 0             0.538462            0.461538  0.461538          0.215385
# 1             0.933333            0.066667  0.066667          0.047619
# 2             1.000000            0.000000  0.033333          0.015873
# 3             0.866667            0.133333  0.133333          0.206349
# 4             0.933333            0.066667  0.066667          0.126984
# 5             1.000000            0.000000  0.033333          0.007937
# 6             1.000000            0.000000  0.033333          0.079365
#
#    d_sensitivity    c_bias  Test_Accuracy_Score
# 0       0.691317  0.442217             0.730769
# 1       0.167305  1.584739             0.782051
# 2       0.313679  1.990754             0.794872
# 3      -0.291617  0.964963             0.666667
# 4      -0.360322  1.320925             0.717949
# 5       0.577908  2.122868             0.807692
# 6      -0.424559  1.621635             0.743590

# %%
# save report on a csv file
exp_n = '_1_'
file_name = 'compare_all_models' + exp_n + '.csv'
df_report.to_csv(file_name, sep=',')

# %% [markdown]
# ## Plots

# %%
# Plot confusion matrix

import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

f, axes = plt.subplots(2, 2, figsize=(15, 10), sharex=True)
sns.despine(left=True)

sns.barplot(x="True_Negatives", y= "Model", data=df_report, ax=axes[0, 0])
sns.barplot(x="False_Positives", y= "Model", data=df_report, ax=axes[0, 1])
sns.barplot(x="False_Negatives", y= "Model", data=df_report, ax=axes[1, 0])
sns.barplot(x="True_Positives", y= "Model", data=df_report, ax=axes[1, 1])


plt.tight_layout()
plt.savefig('confusion_matrix_all_models.pdf')

# %%
# Plot hit rate, false alarm rate, sensitivity, and bias for all models

sns.set(style="whitegrid")

f, axes = plt.subplots(2, 2, figsize=(15, 10), sharex=True)
sns.despine(left=True)

sns.barplot(x="Hit_Rate", y= "Model", data=df_report, ax=axes[0, 0])
sns.barplot(x="False_Alarm_Rate", y= "Model", data=df_report, ax=axes[0, 1])
sns.barplot(x="d_sensitivity", y= "Model", data=df_report, ax=axes[1, 0])
sns.barplot(x="c_bias", y= "Model", data=df_report, ax=axes[1, 1])

plt.tight_layout()
plt.savefig('signal_detection_report_all_models.pdf')

# %%
# Plot test accuracy for all models

sns.set(style="whitegrid")

sns.despine(left=True)

sns.barplot(x="Test_Accuracy_Score", y= "Model", data=df_report)

plt.tight_layout()
plt.savefig('test_accuracy_all_models.pdf')
